# %% [markdown]
# <a href="https://colab.research.google.com/github/JaimeLopezGarrido/labo2025v/blob/main/src/ensembles/Tarea_05_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tarea para el Hogar 05

# %% [markdown]
# Esta Tarea para el Hogar 05 se entrega el final de la cuarta clase
# <br> se espera de usted que intente avanzar con los desafios propuestos y que los traiga terminados para la Clase 05 que será el miercoles 03 de septiembre

# %% [markdown]
# ##  1. Overfitting the Public Leaderboard

# %% [markdown]
# Leer  https://medium.com/hmif-itb/overfitting-the-leaderboard-da25172ac62e
# ( 8 minutos )

# %% [markdown]
# ## 2. Hiperparámetros del LightGBM

# %% [markdown]
# Los objetivos de esta tarea son:
#
#
# *   Aumentar la rentabilidad de la campaña de marketing de retención proactiva de clientes.
# *   Generar un mejor modelo optimizando sus hiperparámetros
# *   Conceptual : investigar los mas relevantes hiperparámetros de LightGBM
# *   Familiarizarse con la Bayesian Optimization, sus largos tiempos de corrida y opciones para reducirlos
# *   Familiarizarse con el uso de máquinas virtuales de Google Colab
# *   Ver un pipeline completo de optimización de hiperparámetros y puesta en producción

# %% [markdown]
# LightGBM cuenta con mas de 60 hiperparámetros, siendo posible utilizar 40 al mismo tiempo, aunque no razonable.
# <br> La documentación oficial de los hiperparámetros de LightGBM es  https://lightgbm.readthedocs.io/en/latest/Parameters.html#core-parameters

# %% [markdown]
# Se lo alerta sobre que una Optimizacion Bayesiana lleva varias horas de corrida, y usted deberá correr VARIAS optimizaciones para descubrir cuales parámetros conviene optimizar.
# <br> A pesar que la próxima clase es recien en viernes 01 de agosto, inicie la tarea con tiempo, aprenda a planificar estratégicamente sus corridas como un@ científ@  de datos.

# %% [markdown]
# Es necesario investigar cuales son los hiperparámetros de LightGBM que vale la pena optimizar en una Bayesian Optimization, ya que los realmente utiles son apenas un reducido subconjunto.
# <br>Usted deberá investigar cuales son los hiperparámetros mas relevantes de LightGBM, su primer alternativa es preguntándole a su amigo con capacidades especiales ChatGPT o sus endogámicos familiares Claude, DeepSeek, Gemini, Grok, etc
# <br> La segunda alternativa es la propia documentación de LightGBM  https://lightgbm.readthedocs.io/en/latest/Parameters-Tuning.html

# %% [markdown]
# Adicionalmente podra buscar información como la que proveen esta diminuta muestra aleatoria de artículos ligeros:
# * https://machinelearningmastery.com/light-gradient-boosted-machine-lightgbm-ensemble/
# *  https://medium.com/@sarahzouinina/a-deep-dive-into-lightgbm-how-to-choose-and-tune-parameters-7c584945842e
# *  https://www.kaggle.com/code/somang1418/tuning-hyperparameters-under-10-minutes-lgbm
# *  https://towardsdatascience.com/beginners-guide-to-the-must-know-lightgbm-hyperparameters-a0005a812702/
#
#
# <br>  La muestra anterior se brinda a modo de ejemplo, usted deberá buscar muuuuchas  fuentes adicionales de información
# <br> Tenga presente que LightGBM es el estado del arte en modelado predictivo para datasets estructurado, que son el 90% del trabajo del 95% de los Data Scientists en Argentina.

# %% [markdown]
# El desafío de esta tarea es:
# * Qué hiperparparámetros conviene optimizar?  Las recomendaciones de los artículos ligeros es siempre sensata?  Sus autores realmente hicieron experimentos o son siemplemente escritores de entretenimiento carente de base científica?
# * Elegidos los hiperparámetros, cual es el  <desde, hasta> que se debe utilizar en la Bayesian Optimization ?
# * Realmente vale la pena optimizar 10 o 16 hiperparámetros al mismo tiempo ?  No resulta contraproducente una búsqueda en un espacio de tal alta dimensionalidad ?

# %% [markdown]
# ---
# # Resumen Hiperparametros
#
# LightGBM utiliza el algoritmo de crecimiento de árbol "leaf-wise" (por hoja), mientras que muchas otras herramientas populares utilizan el crecimiento "depth-wise" (por profundidad).
#
# Parámetros Importantes para el Árbol "Leaf-wise":
#
# - *num_leaves*  = Número máximo de hojas que cada árbol puede tener; controla complejidad.
#
#       Este es el parámetro principal para controlar la complejidad del modelo de árbol. Una profundidad no restringida puede inducir el sobreajuste.$num\_leaves = 2^{(max\_depth)}$ para obtener el mismo número de hojas que un árbol "depth-wise".
#
#       - Tiene que ser menor que 2^{(max\_depth)} para evitar overfitting.
#       - Disminuirlo acelera el entrenamiento y reduce overfitting.
#
# - *min_data_in_leaf* = Número mínimo de observaciones que cada hoja debe contener.
#
#       Muy importante para prevenir overfitting, ya que previene hojas con muy pocos datos. Cientos o miles es suficiente para un conjunto de datos grande.
#       - Si sobreajusta hay que subirlo
#       - Si subajusta hay que bajarlo
#
# - *max_depth* = Profundidad máxima de cada árbol; ≤0 significa sin límite. Disminuirlo reduce tiempo y sobreajuste.
#
#       -1 → sin límite (LightGBM lo decide por num_leaves)
#
#       3–8 → árboles pequeños y conservadores
#
#       8–15 → árboles medianos
#
#       > 15 → árboles muy complejos, riesgo de sobreajuste
#
#
#
# ---
# # Arboles, menos profundos, mas rapidos, pero menos precisos.
#
#
# - Disminuir *max_depth*: Reducir la profundidad máxima del árbol para limitar el crecimiento y el tiempo de entrenamiento.
# - Disminuir *num_leaves*: Reducir el número máximo de nodos hoja por árbol, controlando la complejidad y disminuyendo el tiempo de entrenamiento.
# - Aumentar *min_gain_to_split*: Incrementar la ganancia mínima requerida para una división, evitando divisiones de mejora muy pequeña y acortando el entrenamiento.
# - Aumentar *min_data_in_leaf* y *min_sum_hessian_in_leaf*: Aumentar estos valores para prevenir la creación de nodos de árbol muy específicos (sobreajuste) y reducir el tiempo de entrenamiento.
#
# ---
#
# # Entrenar menos árboles
# *num_iterations*
#
# - Número de árboles o rondas de boosting.
#
# - Valores típicos: 500–2000.
#
# - Menos iteraciones → menos tiempo de entrenamiento.
#
# - Si se reduce num_iterations, conviene subir learning_rate (por ejemplo, de 0.03 a 0.1).
#
# *learning_rate*
#
# - Cuánto se ajusta el modelo en cada iteración.
#
# - Valores típicos: 0.01–0.1.
#
# - No afecta el tiempo de entrenamiento, pero sí la precisión.
#
# *early_stopping_round*
#
# - Detiene el entrenamiento si no mejora tras X iteraciones.
#
# - Ejemplo: early_stopping_round = 50.
#
# - Requiere usar un set de validación.
#
# - Permite ahorrar tiempo sin perder rendimiento.
#
# ---
#
# # Menos divisiones por nodo
# *feature_pre_filter*
#
# Si está en TRUE (por defecto), LightGBM filtra variables con poca información antes de entrenar. Mantenerlo en TRUE para acelerar.
#
# *max_bin*
#
# - Cantidad máxima de bins por variable continua.
#
# - Menor valor = entrenamiento más rápido pero menos preciso.
#
# - Valores típicos: 31–255.
#
# - Reducirlo acorta el tiempo de entrenamiento.
#
# *min_data_in_bin*
#
# - Mínimo de datos por bin.
#
# - Aumentarlo reduce el número de bins y acelera el proceso.
#
# - Valor típico: 3–10.
#
# *feature_fraction*
#
# - Porcentaje de variables usadas en cada árbol.
#
# - Ejemplo: feature_fraction = 0.5 usa el 50% de las variables al azar.
#
# - Reducirlo mejora velocidad y ayuda a evitar sobreajuste.
#
# - Valores típicos: 0.5–0.9.
#
# *max_cat_threshold*
#
# - Número máximo de combinaciones evaluadas para variables categóricas.
#
# - Reducirlo disminuye tiempo de cómputo.
#
# - Valores comunes: 16–64.
#
# ---
#
#
# # Usar menos datos por iteración
# *bagging_fraction* y *bagging_freq*
#
# Permiten usar una muestra aleatoria del dataset en cada iteración.
#
# Ejemplo:
#
# - bagging_fraction = 0.75 → usa el 75% de los datos.
#
# - bagging_freq = 5 → cambia la muestra cada 5 iteraciones.
#
# Reducir bagging_fraction acelera el entrenamiento y puede mejorar generalización.
#
# ---
#
# # Para una Mejor Precisión
#
# Para maximizar la precisión del modelo (generalmente a costa de un mayor tiempo de entrenamiento):
#
# - Usar un max_bin grande (puede ser más lento).
#
# - Usar un learning_rate pequeño con un num_iterations grande.
#
# - Usar un num_leaves grande (puede causar sobreajuste).
#
# - Usar datos de entrenamiento más grandes.
#
# - Probar el booster dart.
#
# **Cómo Lidiar con el Sobreajuste**
#
# Para ayudar al modelo a generalizar mejor y evitar el sobreajuste:
#
# - Usar un max_bin pequeño.
#
# - Usar un num_leaves pequeño.
#
# - Usar min_data_in_leaf y min_sum_hessian_in_leaf.
#
# - Usar bagging (agregación de bootstrap) configurando bagging_fraction y bagging_freq.
#
# - Usar submuestreo de características (feature sub-sampling) configurando feature_fraction.
#
# - Usar datos de entrenamiento más grandes.
#
# - Probar lambda_l1, lambda_l2 y min_gain_to_split para regularización.
#
# - Probar max_depth para evitar el crecimiento de árboles profundos.
#
# - Probar el algoritmo extra_trees.
#
# - Probar aumentar path_smooth.

# %% [markdown]
# #### 2.1  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Mounted at /content/.drive

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/labo1"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/labo1" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets



archivo_origen="https://storage.googleapis.com/open-courses/austral2025-af91/dataset_pequeno.csv"
archivo_destino="/content/datasets/dataset_pequeno.csv"
archivo_destino_bucket="/content/buckets/b1/datasets/dataset_pequeno.csv"

if ! test -f $archivo_destino_bucket; then
  wget  $archivo_origen  -O $archivo_destino_bucket
fi


if ! test -f $archivo_destino; then
  cp  $archivo_destino_bucket  $archivo_destino
fi

# %% [markdown]
# ### 2.2 Optimizacion Hiperparámetros

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje R Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# ### 2.2.1 Inicio

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Mon Nov 03 12:22:04 PM 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  660381 35.3 1454462    77.7 1454462  77.7
# Vcells 1226627  9.4 8388608    64.0 1975128  15.1

# %% [markdown]
# ### 2.2.2 Carga de Librerias

# %%
# cargo las librerias que necesito
require("data.table")
require("parallel")

if( !require("primes") ) install.packages("primes")
require("primes")

if( !require("utils") ) install.packages("utils")
require("utils")

if( !require("rlist") ) install.packages("rlist")
require("rlist")

if( !require("yaml")) install.packages("yaml")
require("yaml")

if( !require("lightgbm") ) install.packages("lightgbm")
require("lightgbm")

if( !require("DiceKriging") ) install.packages("DiceKriging")
require("DiceKriging")

if( !require("mlrMBO") ) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: data.table
#
# Loading required package: parallel
#
# Loading required package: primes
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘primes’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: primes
#
# Loading required package: rlist
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘rlist’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘XML’
#
#
# Loading required package: rlist
#
# Loading required package: yaml
#
# Loading required package: lightgbm
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘lightgbm’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: lightgbm
#
# Loading required package: DiceKriging
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘DiceKriging’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘mlrMBO’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘fastmatch’, ‘RcppArmadillo’, ‘mlr’, ‘ParamHelpers’, ‘smoof’, ‘BBmisc’, ‘checkmate’, ‘lhs’, ‘parallelMap’
#
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames

# %% [markdown]
# ### 2.2.3 Definicion de Parametros

# %% [markdown]
# aqui debe cargar SU semilla primigenia
# <br>recuerde cambiar el numero de experimento en cada corrida nueva

# %%
PARAM <- list()

# %%
PARAM$experimento <- 2
PARAM$semilla_primigenia <- 100007

# %%
PARAM$kaggle$competencia <- "labo-i-2025-virtual-analista-sr"
PARAM$kaggle$cortes <- seq(10000, 12000, by= 500)

# %%
# un undersampling de 0.1  toma solo el 10% de los CONTINUA
# undersampling de 1.0  implica tomar TODOS los datos

PARAM$trainingstrategy$undersampling <- 0.5

# %%
# Parametros LightGBM

PARAM$hyperparametertuning$xval_folds <- 5

# parametros fijos del LightGBM que se pisaran con la parte variable de la BO
PARAM$lgbm$param_fijos <-  list(
  boosting= "gbdt", # puede ir  dart  , ni pruebe random_forest
  objective= "binary",
  metric= "auc",
  first_metric_only= FALSE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  force_row_wise= TRUE, # para reducir warnings
  verbosity= -100,

  seed= PARAM$semilla_primigenia,

  max_depth= -1L, # -1 significa no limitar,  por ahora lo dejo fijo
  min_gain_to_split= 0, # min_gain_to_split >= 0
  min_sum_hessian_in_leaf= 0.001, #  min_sum_hessian_in_leaf >= 0.0
  lambda_l1= 0.0, # lambda_l1 >= 0.0
  lambda_l2= 0.0, # lambda_l2 >= 0.0
  max_bin= 31L, # lo debo dejar fijo, no participa de la BO

  bagging_fraction= 1.0, # 0.0 < bagging_fraction <= 1.0
  pos_bagging_fraction= 1.0, # 0.0 < pos_bagging_fraction <= 1.0
  neg_bagging_fraction= 1.0, # 0.0 < neg_bagging_fraction <= 1.0
  is_unbalance= FALSE, #
  scale_pos_weight= 1.0, # scale_pos_weight > 0.0

  drop_rate= 0.1, # 0.0 < neg_bagging_fraction <= 1.0
  max_drop= 50, # <=0 means no limit
  skip_drop= 0.5, # 0.0 <= skip_drop <= 1.0

  extra_trees= FALSE,

  num_iterations= 1200,
  learning_rate= 0.02,
  feature_fraction= 0.5,
  num_leaves= 750,
  min_data_in_leaf= 5000
)

# %% [markdown]
# Aqui se definen los hiperparámetros de LightGBM que participan de la Bayesian Optimization
# <br> si es un numero entero debe ir  makeIntegerParam
# <br> si es un numero real (con decimales) debe ir  makeNumericParam
# <br> es muy importante leer cuales son un lower y upper  permitidos y ademas razonables

# %%
# Aqui se cargan los bordes de los hiperparametros de la BO
#PARAM$hypeparametertuning$hs <- makeParamSet(
#  makeNumericParam("learning_rate", lower = 0.01, upper = 0.05),
#  makeIntegerParam("num_leaves", lower = 16L, upper = 128L),
#  makeNumericParam("feature_fraction", lower = 0.5, upper = 0.9),
#  makeNumericParam("bagging_fraction", lower = 0.7, upper = 1.0),
#  makeIntegerParam("min_data_in_leaf", lower = 20L, upper = 200L),
#  makeNumericParam("lambda_l1", lower = 0, upper = 10),
#  makeNumericParam("lambda_l2", lower = 0, upper = 10),
#  makeNumericParam("min_gain_to_split", lower = 0, upper = 0.5),
#  makeIntegerParam("max_depth", lower = -1L, upper = 10L)
#)

PARAM$hypeparametertuning$hs <- makeParamSet(
makeNumericParam("learning_rate", lower = 0.01, upper = 0.05),
makeIntegerParam("num_leaves", lower = 16L, upper = 128L),
makeNumericParam("feature_fraction", lower = 0.5, upper = 0.9),
makeNumericParam("bagging_fraction", lower = 0.7, upper = 1.0),
makeIntegerParam("min_data_in_leaf", lower = 20L, upper = 200L),
makeNumericParam("lambda_l1", lower = 0, upper = 10),
makeNumericParam("lambda_l2", lower = 0, upper = 10),
makeNumericParam("min_gain_to_split", lower = 0, upper = 0.5),
makeIntegerParam("max_depth", lower = -1L, upper = 10L) )

# %% [markdown]
# A mayor cantidad de hiperparámetros, se debe aumentar las iteraciones de la Bayesian Optimization
# <br> 30 es un valor muy tacaño, pero corre rápido
# <br> deberia partir de 50, alcanzando los 100 si se dispone de tiempo

# %%
PARAM$hyperparametertuning$iteraciones <- 35 # iteraciones bayesianas

# %% [markdown]
# ### 2.2.4  Preprocesamiento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("HT", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %%
# lectura del dataset

dataset <- fread("/content/datasets/dataset_pequeno.csv")

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# paso la clase a binaria que tome valores {0,1}  enteros
#  BAJA+1 y BAJA+2  son  1,   CONTINUA es 0

dataset_train[,
  clase01 := ifelse(clase_ternaria %in% c("BAJA+2","BAJA+1"), 1L, 0L)
]

# %%
# defino los datos que forma parte del training
# aqui se hace el undersampling de los CONTINUA
# notar que para esto utilizo la SEGUNDA semilla

set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset_train[, azar := runif(nrow(dataset_train))]
dataset_train[, training := 0L]

dataset_train[
  foto_mes %in% c(202107) &
    (azar <= PARAM$trainingstrategy$undersampling | clase_ternaria %in% c("BAJA+1", "BAJA+2")),
  training := 1L
]

# %%
# los campos que se van a utilizar

campos_buenos <- setdiff(
  colnames(dataset_train),
  c("clase_ternaria", "clase01", "azar", "training")
)

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[training == 1L, campos_buenos, with= FALSE]),
  label= dataset_train[training == 1L, clase01],
  free_raw_data= FALSE
)

nrow(dtrain)
ncol(dtrain)
# Out:
# [1] 83029
# [1] 154

# %% [markdown]
# 2.2.5 Configuracion Bayesian Optimization

# %%
# En el argumento x llegan los parmaetros de la bayesiana
#  devuelve la AUC en cross validation del modelo entrenado

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelocv <- lgb.cv(
    data= dtrain,
    nfold= PARAM$hyperparametertuning$xval_folds,
    stratified= TRUE,
    param= param_completo
  )

  # obtengo la ganancia
  AUC <- modelocv$best_score

  # hago espacio en la memoria
  rm(modelocv)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %%
# Aqui comienza la configuracion de la Bayesian Optimization

# en este archivo quedan la evolucion binaria de la BO
kbayesiana <- "bayesiana.RDATA"

funcion_optimizar <- EstimarGanancia_AUC_lightgbm # la funcion que voy a maximizar

configureMlr(show.learner.output= FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo

obj.fun <- makeSingleObjectiveFunction(
  fn= funcion_optimizar, # la funcion que voy a maximizar
  minimize= FALSE, # estoy Maximizando la ganancia
  noisy= TRUE,
  par.set= PARAM$hypeparametertuning$hs, # definido al comienzo del programa
  has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
  save.on.disk.at.time= 600, # se graba cada 600 segundos
  save.file.path= kbayesiana
) # se graba cada 600 segundos

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
  ctrl,
  iters= PARAM$hyperparametertuning$iteraciones
) # cantidad de iteraciones

# defino el método estandar para la creacion de los puntos iniciales,
# los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit= makeMBOInfillCritEI())

# establezco la funcion que busca el maximo
surr.km <- makeLearner(
  "regr.km",
  predict.type= "se",
  covtype= "matern3_2",
  control= list(trace= TRUE)
)

# %% [markdown]
# 2.2.6 Corrida Bayesian Optimization

# %%
# inicio la optimizacion bayesiana, retomando si ya existe
# es la celda mas lenta de todo el notebook

if (!file.exists(kbayesiana)) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue(kbayesiana) # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Mon Nov 03 12:38:34 PM 2025 AUC 0.919865877872154
#
# Mon Nov 03 12:39:55 PM 2025 AUC 0.928523082163589
#
# Mon Nov 03 12:41:28 PM 2025 AUC 0.928410533518601
#
# Mon Nov 03 12:43:09 PM 2025 AUC 0.928178340526996
#
# Mon Nov 03 12:45:22 PM 2025 AUC 0.92865473656092
#
# Mon Nov 03 12:47:02 PM 2025 AUC 0.929991767872126
#
# Mon Nov 03 12:48:22 PM 2025 AUC 0.926681382416943
#
# Mon Nov 03 12:49:44 PM 2025 AUC 0.925629573950277
#
# Mon Nov 03 12:51:16 PM 2025 AUC 0.93007160123414
#
# Mon Nov 03 12:53:55 PM 2025 AUC 0.929414878647066
#
# Mon Nov 03 12:55:47 PM 2025 AUC 0.929956556149647
#
# Mon Nov 03 12:57:53 PM 2025 AUC 0.928933260264194
#
# Mon Nov 03 01:00:20 PM 2025 AUC 0.929677150515104
#
# Mon Nov 03 01:03:42 PM 2025 AUC 0.928384239651961
#
# Mon Nov 03 01:06:40 PM 2025 AUC 0.928882609368019
#
# Mon Nov 03 01:08:48 PM 2025 AUC 0.929424952235628
#
# Mon Nov 03 01:12:13 PM 2025 AUC 0.929520884655574
#
# Mon Nov 03 01:13:49 PM 2025 AUC 0.928322624544404
#
# Mon Nov 03 01:17:25 PM 2025 AUC 0.930680473376287
#
# Mon Nov 03 01:20:15 PM 2025 AUC 0.929871762300379
#
# Mon Nov 03 01:22:19 PM 2025 AUC 0.928580586093188
#
# Mon Nov 03 01:23:57 PM 2025 AUC 0.929399204364752
#
# Mon Nov 03 01:25:31 PM 2025 AUC 0.929971930870533
#
# Mon Nov 03 01:27:55 PM 2025 AUC 0.929921605597635
#
# Mon Nov 03 01:30:22 PM 2025 AUC 0.929107249415994
#
# Mon Nov 03 01:32:25 PM 2025 AUC 0.929605033018444
#
# Mon Nov 03 01:34:54 PM 2025 AUC 0.929631440992489
#
# Mon Nov 03 01:38:06 PM 2025 AUC 0.928559334564272
#
# Mon Nov 03 01:40:02 PM 2025 AUC 0.92922603187191
#
# Mon Nov 03 01:41:19 PM 2025 AUC 0.926848712121024
#
# Mon Nov 03 01:45:25 PM 2025 AUC 0.930931263015502
#
# Mon Nov 03 01:46:34 PM 2025 AUC 0.92142218235403
#
# Mon Nov 03 01:48:13 PM 2025 AUC 0.929547382160319
#
# Mon Nov 03 01:51:50 PM 2025 AUC 0.929211780598798
#
# Mon Nov 03 01:52:58 PM 2025 AUC 0.920221391981363
#
# Mon Nov 03 01:54:56 PM 2025 AUC 0.929018534827482
#
# [mbo] 0: learning_rate=0.031; num_leaves=116; feature_fraction=0.751; bagging_fraction=0.754; min_data_in_leaf=72; lambda_l1=5.82; lambda_l2=6.39; min_gain_to_split=0.237; max_depth=1 : y = 0.92 : 74.1 secs : initdesign
#
# [mbo] 0: learning_rate=0.0395; num_leaves=109; feature_fraction=0.756; bagging_fraction=0.873; min_data_in_leaf=97; lambda_l1=2.42; lambda_l2=4.25; min_gain_to_split=0.195; max_depth=2 : y = 0.929 : 81.9 secs : initdesign
#
# [mbo] 0: learning_rate=0.0234; num_leaves=64; feature_fraction=0.795; bagging_fraction=0.977; min_data_in_leaf=130; lambda_l1=9.9; lambda_l2=5.03; min_gain_to_split=0.22; max_depth=4 : y = 0.928 : 92.6 secs : initdesign
#
# [mbo] 0: learning_rate=0.0328; num_leaves=53; feature_fraction=0.636; bagging_fraction=0.772; min_data_in_leaf=26; lambda_l1=6.29; lambda_l2=5.97; min_gain_to_split=0.343; max_depth=3 : y = 0.928 : 101.0 secs : initdesign
#
# [mbo] 0: learning_rate=0.0179; num_leaves=61; feature_fraction=0.683; bagging_fraction=0.842; min_data_in_leaf=172; lambda_l1=5.33; lambda_l2=4.66; min_gain_to_split=0.161; max_depth=9 : y = 0.929 : 133.5 secs : initdesign
#
# [mbo] 0: learning_rate=0.0373; num_leaves=67; feature_fraction=0.786; bagging_fraction=0.96; min_data_in_leaf=108; lambda_l1=2.84; lambda_l2=3.35; min_gain_to_split=0.225; max_depth=8 : y = 0.93 : 99.9 secs : initdesign
#
# [mbo] 0: learning_rate=0.0294; num_leaves=36; feature_fraction=0.774; bagging_fraction=0.785; min_data_in_leaf=67; lambda_l1=1.9; lambda_l2=6.99; min_gain_to_split=0.0696; max_depth=2 : y = 0.927 : 79.9 secs : initdesign
#
# [mbo] 0: learning_rate=0.0191; num_leaves=81; feature_fraction=0.716; bagging_fraction=0.855; min_data_in_leaf=156; lambda_l1=3.35; lambda_l2=3.16; min_gain_to_split=0.391; max_depth=2 : y = 0.926 : 81.6 secs : initdesign
#
# [mbo] 0: learning_rate=0.0337; num_leaves=82; feature_fraction=0.694; bagging_fraction=0.808; min_data_in_leaf=141; lambda_l1=8.15; lambda_l2=9.59; min_gain_to_split=0.124; max_depth=5 : y = 0.93 : 92.5 secs : initdesign
#
# [mbo] 0: learning_rate=0.0127; num_leaves=59; feature_fraction=0.828; bagging_fraction=0.836; min_data_in_leaf=165; lambda_l1=6.04; lambda_l2=5.3; min_gain_to_split=0.152; max_depth=0 : y = 0.929 : 158.8 secs : initdesign
#
# [mbo] 0: learning_rate=0.036; num_leaves=91; feature_fraction=0.733; bagging_fraction=0.884; min_data_in_leaf=150; lambda_l1=1.55; lambda_l2=9.27; min_gain_to_split=0.373; max_depth=0 : y = 0.93 : 112.1 secs : initdesign
#
# [mbo] 0: learning_rate=0.0348; num_leaves=99; feature_fraction=0.879; bagging_fraction=0.9; min_data_in_leaf=41; lambda_l1=3.77; lambda_l2=7.72; min_gain_to_split=0.0576; max_depth=6 : y = 0.929 : 125.4 secs : initdesign
#
# [mbo] 0: learning_rate=0.0222; num_leaves=120; feature_fraction=0.599; bagging_fraction=0.794; min_data_in_leaf=121; lambda_l1=8.73; lambda_l2=4; min_gain_to_split=0.325; max_depth=5 : y = 0.93 : 146.8 secs : initdesign
#
# [mbo] 0: learning_rate=0.0463; num_leaves=76; feature_fraction=0.51; bagging_fraction=0.72; min_data_in_leaf=52; lambda_l1=8.42; lambda_l2=0.823; min_gain_to_split=0.496; max_depth=10 : y = 0.928 : 202.9 secs : initdesign
#
# [mbo] 0: learning_rate=0.0212; num_leaves=40; feature_fraction=0.582; bagging_fraction=0.957; min_data_in_leaf=147; lambda_l1=1.06; lambda_l2=3.85; min_gain_to_split=0.132; max_depth=4 : y = 0.929 : 177.0 secs : initdesign
#
# [mbo] 0: learning_rate=0.0115; num_leaves=71; feature_fraction=0.802; bagging_fraction=0.935; min_data_in_leaf=133; lambda_l1=4.85; lambda_l2=1.74; min_gain_to_split=0.438; max_depth=8 : y = 0.929 : 128.9 secs : initdesign
#
# [mbo] 0: learning_rate=0.0469; num_leaves=41; feature_fraction=0.523; bagging_fraction=0.864; min_data_in_leaf=118; lambda_l1=6.39; lambda_l2=1.2; min_gain_to_split=0.262; max_depth=-1 : y = 0.93 : 204.8 secs : initdesign
#
# [mbo] 0: learning_rate=0.0313; num_leaves=100; feature_fraction=0.857; bagging_fraction=0.924; min_data_in_leaf=78; lambda_l1=9.45; lambda_l2=7.8; min_gain_to_split=0.194; max_depth=0 : y = 0.928 : 95.4 secs : initdesign
#
# [mbo] 0: learning_rate=0.0266; num_leaves=86; feature_fraction=0.549; bagging_fraction=0.822; min_data_in_leaf=93; lambda_l1=2.74; lambda_l2=8.79; min_gain_to_split=0.273; max_depth=7 : y = 0.931 : 216.8 secs : initdesign
#
# [mbo] 0: learning_rate=0.0425; num_leaves=17; feature_fraction=0.577; bagging_fraction=0.916; min_data_in_leaf=59; lambda_l1=2.09; lambda_l2=0.299; min_gain_to_split=0.413; max_depth=8 : y = 0.93 : 169.2 secs : initdesign
#
# [mbo] 0: learning_rate=0.0277; num_leaves=44; feature_fraction=0.608; bagging_fraction=0.729; min_data_in_leaf=193; lambda_l1=7.9; lambda_l2=2.36; min_gain_to_split=0.472; max_depth=7 : y = 0.929 : 124.8 secs : initdesign
#
# [mbo] 0: learning_rate=0.0201; num_leaves=73; feature_fraction=0.666; bagging_fraction=0.971; min_data_in_leaf=184; lambda_l1=7.55; lambda_l2=9.08; min_gain_to_split=0.385; max_depth=5 : y = 0.929 : 98.0 secs : initdesign
#
# [mbo] 0: learning_rate=0.0481; num_leaves=105; feature_fraction=0.818; bagging_fraction=0.71; min_data_in_leaf=112; lambda_l1=5; lambda_l2=6.38; min_gain_to_split=0.0886; max_depth=3 : y = 0.93 : 94.1 secs : initdesign
#
# [mbo] 0: learning_rate=0.0278; num_leaves=93; feature_fraction=0.675; bagging_fraction=0.832; min_data_in_leaf=24; lambda_l1=0.792; lambda_l2=7.34; min_gain_to_split=0.17; max_depth=-1 : y = 0.93 : 143.2 secs : initdesign
#
# [mbo] 0: learning_rate=0.0141; num_leaves=111; feature_fraction=0.744; bagging_fraction=0.927; min_data_in_leaf=63; lambda_l1=3.21; lambda_l2=1.43; min_gain_to_split=0.0486; max_depth=6 : y = 0.929 : 147.4 secs : initdesign
#
# [mbo] 0: learning_rate=0.0166; num_leaves=49; feature_fraction=0.652; bagging_fraction=0.762; min_data_in_leaf=48; lambda_l1=9.09; lambda_l2=0.166; min_gain_to_split=0.11; max_depth=10 : y = 0.93 : 122.7 secs : initdesign
#
# [mbo] 0: learning_rate=0.0103; num_leaves=21; feature_fraction=0.842; bagging_fraction=0.877; min_data_in_leaf=80; lambda_l1=4.21; lambda_l2=8.18; min_gain_to_split=0.313; max_depth=9 : y = 0.93 : 148.9 secs : initdesign
#
# [mbo] 0: learning_rate=0.0416; num_leaves=115; feature_fraction=0.562; bagging_fraction=0.991; min_data_in_leaf=161; lambda_l1=0.169; lambda_l2=2.9; min_gain_to_split=0.425; max_depth=4 : y = 0.929 : 192.9 secs : initdesign
#
# [mbo] 0: learning_rate=0.0153; num_leaves=122; feature_fraction=0.847; bagging_fraction=0.738; min_data_in_leaf=177; lambda_l1=6.72; lambda_l2=5.56; min_gain_to_split=0.293; max_depth=6 : y = 0.929 : 115.5 secs : initdesign
#
# [mbo] 0: learning_rate=0.0434; num_leaves=33; feature_fraction=0.875; bagging_fraction=0.947; min_data_in_leaf=136; lambda_l1=9.35; lambda_l2=4.95; min_gain_to_split=0.448; max_depth=-1 : y = 0.927 : 76.8 secs : initdesign
#
# [mbo] 0: learning_rate=0.0403; num_leaves=27; feature_fraction=0.544; bagging_fraction=0.81; min_data_in_leaf=198; lambda_l1=1.35; lambda_l2=2.61; min_gain_to_split=0.027; max_depth=10 : y = 0.931 : 246.4 secs : initdesign
#
# [mbo] 0: learning_rate=0.0451; num_leaves=22; feature_fraction=0.894; bagging_fraction=0.778; min_data_in_leaf=30; lambda_l1=6.97; lambda_l2=2.01; min_gain_to_split=0.04; max_depth=1 : y = 0.921 : 68.5 secs : initdesign
#
# [mbo] 0: learning_rate=0.0498; num_leaves=30; feature_fraction=0.627; bagging_fraction=0.742; min_data_in_leaf=88; lambda_l1=4.45; lambda_l2=9.88; min_gain_to_split=0.48; max_depth=7 : y = 0.93 : 99.3 secs : initdesign
#
# [mbo] 0: learning_rate=0.0177; num_leaves=126; feature_fraction=0.516; bagging_fraction=0.896; min_data_in_leaf=186; lambda_l1=3.91; lambda_l2=8.37; min_gain_to_split=0.00194; max_depth=3 : y = 0.929 : 216.8 secs : initdesign
#
# [mbo] 0: learning_rate=0.025; num_leaves=53; feature_fraction=0.706; bagging_fraction=0.701; min_data_in_leaf=100; lambda_l1=0.349; lambda_l2=1.1; min_gain_to_split=0.359; max_depth=1 : y = 0.92 : 68.6 secs : initdesign
#
# [mbo] 0: learning_rate=0.038; num_leaves=96; feature_fraction=0.62; bagging_fraction=0.996; min_data_in_leaf=36; lambda_l1=7.23; lambda_l2=6.88; min_gain_to_split=0.286; max_depth=9 : y = 0.929 : 117.8 secs : initdesign
#
# Saved the current state after iteration 1 in the file bayesiana.RDATA.
#
# Mon Nov 03 01:57:04 PM 2025 AUC 0.929306610780278
#
# [mbo] 1: learning_rate=0.0291; num_leaves=16; feature_fraction=0.85; bagging_fraction=0.956; min_data_in_leaf=194; lambda_l1=0.138; lambda_l2=6.03; min_gain_to_split=0.0626; max_depth=10 : y = 0.929 : 126.3 secs : infill_ei
#
# Mon Nov 03 02:01:22 PM 2025 AUC 0.93024361470657
#
# [mbo] 2: learning_rate=0.0135; num_leaves=26; feature_fraction=0.501; bagging_fraction=0.702; min_data_in_leaf=194; lambda_l1=0.398; lambda_l2=2.26; min_gain_to_split=0.0108; max_depth=10 : y = 0.93 : 257.4 secs : infill_ei
#
# Mon Nov 03 02:04:02 PM 2025 AUC 0.929140684127545
#
# [mbo] 3: learning_rate=0.0151; num_leaves=128; feature_fraction=0.659; bagging_fraction=0.806; min_data_in_leaf=22; lambda_l1=0.188; lambda_l2=9.95; min_gain_to_split=0.0196; max_depth=7 : y = 0.929 : 159.2 secs : infill_ei
#
# Mon Nov 03 02:05:32 PM 2025 AUC 0.930123599690485
#
# [mbo] 4: learning_rate=0.0492; num_leaves=45; feature_fraction=0.68; bagging_fraction=0.872; min_data_in_leaf=138; lambda_l1=7.68; lambda_l2=9.99; min_gain_to_split=0.0647; max_depth=3 : y = 0.93 : 89.4 secs : infill_ei
#
# Saved the current state after iteration 5 in the file bayesiana.RDATA.
#
# Mon Nov 03 02:09:17 PM 2025 AUC 0.930715603221882
#
# [mbo] 5: learning_rate=0.0296; num_leaves=93; feature_fraction=0.501; bagging_fraction=0.999; min_data_in_leaf=106; lambda_l1=1.83; lambda_l2=9.88; min_gain_to_split=0.416; max_depth=7 : y = 0.931 : 224.4 secs : infill_ei
#
# Mon Nov 03 02:13:12 PM 2025 AUC 0.930554699069594
#
# [mbo] 6: learning_rate=0.0272; num_leaves=22; feature_fraction=0.556; bagging_fraction=0.802; min_data_in_leaf=122; lambda_l1=3.22; lambda_l2=4.38; min_gain_to_split=0.0528; max_depth=8 : y = 0.931 : 233.5 secs : infill_ei
#
# Mon Nov 03 02:16:48 PM 2025 AUC 0.930300993507529
#
# [mbo] 7: learning_rate=0.0369; num_leaves=91; feature_fraction=0.518; bagging_fraction=0.706; min_data_in_leaf=46; lambda_l1=5.92; lambda_l2=9.96; min_gain_to_split=0.223; max_depth=8 : y = 0.93 : 214.9 secs : infill_ei
#
# Saved the current state after iteration 8 in the file bayesiana.RDATA.
#
# Mon Nov 03 02:20:33 PM 2025 AUC 0.929948932337097
#
# [mbo] 8: learning_rate=0.0424; num_leaves=23; feature_fraction=0.504; bagging_fraction=0.83; min_data_in_leaf=200; lambda_l1=8.19; lambda_l2=0.247; min_gain_to_split=0.000719; max_depth=10 : y = 0.93 : 224.5 secs : infill_ei
#
# Mon Nov 03 02:25:29 PM 2025 AUC 0.929191011145447
#
# [mbo] 9: learning_rate=0.0411; num_leaves=124; feature_fraction=0.516; bagging_fraction=0.789; min_data_in_leaf=168; lambda_l1=0.0535; lambda_l2=4.36; min_gain_to_split=0.000554; max_depth=10 : y = 0.929 : 295.1 secs : infill_ei
#
# Mon Nov 03 02:28:39 PM 2025 AUC 0.928192006329443
#
# [mbo] 10: learning_rate=0.0455; num_leaves=16; feature_fraction=0.576; bagging_fraction=0.781; min_data_in_leaf=52; lambda_l1=0.393; lambda_l2=0.0233; min_gain_to_split=0.00176; max_depth=10 : y = 0.928 : 189.1 secs : infill_ei
#
# Saved the current state after iteration 11 in the file bayesiana.RDATA.
#
# Mon Nov 03 02:32:28 PM 2025 AUC 0.930901060377302
#
# [mbo] 11: learning_rate=0.0375; num_leaves=17; feature_fraction=0.506; bagging_fraction=0.819; min_data_in_leaf=200; lambda_l1=0.0705; lambda_l2=2.2; min_gain_to_split=0.394; max_depth=10 : y = 0.931 : 227.9 secs : infill_ei
#
# Mon Nov 03 02:35:28 PM 2025 AUC 0.928978841502755
#
# [mbo] 12: learning_rate=0.05; num_leaves=41; feature_fraction=0.563; bagging_fraction=0.715; min_data_in_leaf=168; lambda_l1=9.98; lambda_l2=7.4; min_gain_to_split=0.109; max_depth=8 : y = 0.929 : 179.1 secs : infill_ei
#
# Mon Nov 03 02:39:36 PM 2025 AUC 0.930102874991639
#
# [mbo] 13: learning_rate=0.0201; num_leaves=18; feature_fraction=0.534; bagging_fraction=0.817; min_data_in_leaf=180; lambda_l1=2.84; lambda_l2=8.56; min_gain_to_split=0.239; max_depth=8 : y = 0.93 : 247.6 secs : infill_ei
#
# Saved the current state after iteration 14 in the file bayesiana.RDATA.
#
# Mon Nov 03 02:43:05 PM 2025 AUC 0.93082178428173
#
# [mbo] 14: learning_rate=0.0139; num_leaves=22; feature_fraction=0.59; bagging_fraction=0.891; min_data_in_leaf=31; lambda_l1=2.01; lambda_l2=9.31; min_gain_to_split=0.0282; max_depth=8 : y = 0.931 : 208.0 secs : infill_ei
#
# Mon Nov 03 02:47:02 PM 2025 AUC 0.930015012615125
#
# [mbo] 15: learning_rate=0.011; num_leaves=55; feature_fraction=0.578; bagging_fraction=0.747; min_data_in_leaf=69; lambda_l1=0.0223; lambda_l2=7.26; min_gain_to_split=0.11; max_depth=8 : y = 0.93 : 235.8 secs : infill_ei
#
# Mon Nov 03 02:50:12 PM 2025 AUC 0.929910742001073
#
# [mbo] 16: learning_rate=0.0256; num_leaves=18; feature_fraction=0.582; bagging_fraction=0.981; min_data_in_leaf=67; lambda_l1=7.03; lambda_l2=9.85; min_gain_to_split=0.0432; max_depth=8 : y = 0.93 : 188.7 secs : infill_ei
#
# Saved the current state after iteration 17 in the file bayesiana.RDATA.
#
# Mon Nov 03 02:53:00 PM 2025 AUC 0.929871303750923
#
# [mbo] 17: learning_rate=0.0403; num_leaves=90; feature_fraction=0.807; bagging_fraction=0.885; min_data_in_leaf=126; lambda_l1=0.169; lambda_l2=8.92; min_gain_to_split=0.0589; max_depth=8 : y = 0.93 : 167.4 secs : infill_ei
#
# Mon Nov 03 02:57:34 PM 2025 AUC 0.930558357673492
#
# [mbo] 18: learning_rate=0.0346; num_leaves=58; feature_fraction=0.507; bagging_fraction=0.996; min_data_in_leaf=116; lambda_l1=3.35; lambda_l2=9.82; min_gain_to_split=0.000328; max_depth=7 : y = 0.931 : 273.9 secs : infill_ei
#
# Mon Nov 03 03:02:28 PM 2025 AUC 0.930208870305371
#
# [mbo] 19: learning_rate=0.0256; num_leaves=119; feature_fraction=0.532; bagging_fraction=0.904; min_data_in_leaf=20; lambda_l1=3.03; lambda_l2=5.15; min_gain_to_split=0.00121; max_depth=8 : y = 0.93 : 292.4 secs : infill_ei
#
# Saved the current state after iteration 20 in the file bayesiana.RDATA.
#
# Mon Nov 03 03:04:35 PM 2025 AUC 0.930456211599289
#
# [mbo] 20: learning_rate=0.0349; num_leaves=16; feature_fraction=0.817; bagging_fraction=0.73; min_data_in_leaf=20; lambda_l1=2.87; lambda_l2=2.07; min_gain_to_split=0.00588; max_depth=8 : y = 0.93 : 126.5 secs : infill_ei
#
# Mon Nov 03 03:07:40 PM 2025 AUC 0.930486057012355
#
# [mbo] 21: learning_rate=0.029; num_leaves=24; feature_fraction=0.58; bagging_fraction=0.782; min_data_in_leaf=200; lambda_l1=3.39; lambda_l2=8.78; min_gain_to_split=0.257; max_depth=10 : y = 0.93 : 183.8 secs : infill_ei
#
# Mon Nov 03 03:11:19 PM 2025 AUC 0.929943654114623
#
# [mbo] 22: learning_rate=0.0452; num_leaves=127; feature_fraction=0.5; bagging_fraction=0.902; min_data_in_leaf=113; lambda_l1=3.31; lambda_l2=9.09; min_gain_to_split=0.224; max_depth=7 : y = 0.93 : 218.1 secs : infill_ei
#
# Mon Nov 03 03:15:41 PM 2025 AUC 0.931065238616854
#
# [mbo] 23: learning_rate=0.0161; num_leaves=43; feature_fraction=0.524; bagging_fraction=0.989; min_data_in_leaf=80; lambda_l1=1.51; lambda_l2=2.12; min_gain_to_split=0.256; max_depth=7 : y = 0.931 : 262.0 secs : infill_ei
#
# Saved the current state after iteration 24 in the file bayesiana.RDATA.
#
# Mon Nov 03 03:19:39 PM 2025 AUC 0.929683620299863
#
# [mbo] 24: learning_rate=0.0307; num_leaves=44; feature_fraction=0.518; bagging_fraction=0.929; min_data_in_leaf=75; lambda_l1=0.386; lambda_l2=5.75; min_gain_to_split=0.32; max_depth=10 : y = 0.93 : 236.2 secs : infill_ei
#
# Mon Nov 03 03:23:25 PM 2025 AUC 0.930144297843814
#
# [mbo] 25: learning_rate=0.0106; num_leaves=24; feature_fraction=0.572; bagging_fraction=0.987; min_data_in_leaf=96; lambda_l1=2.33; lambda_l2=7; min_gain_to_split=0.248; max_depth=7 : y = 0.93 : 225.9 secs : infill_ei
#
# Mon Nov 03 03:27:20 PM 2025 AUC 0.930513942409819
#
# [mbo] 26: learning_rate=0.0119; num_leaves=70; feature_fraction=0.578; bagging_fraction=0.853; min_data_in_leaf=81; lambda_l1=5.39; lambda_l2=9.81; min_gain_to_split=0.193; max_depth=10 : y = 0.931 : 234.0 secs : infill_ei
#
# Saved the current state after iteration 27 in the file bayesiana.RDATA.
#
# Mon Nov 03 03:31:17 PM 2025 AUC 0.93016235154414
#
# [mbo] 27: learning_rate=0.0179; num_leaves=58; feature_fraction=0.535; bagging_fraction=1; min_data_in_leaf=35; lambda_l1=3.96; lambda_l2=8.14; min_gain_to_split=0.351; max_depth=5 : y = 0.93 : 235.6 secs : infill_ei
#
# Mon Nov 03 03:35:12 PM 2025 AUC 0.929588569506679
#
# [mbo] 28: learning_rate=0.0296; num_leaves=70; feature_fraction=0.504; bagging_fraction=0.958; min_data_in_leaf=61; lambda_l1=0.909; lambda_l2=0.623; min_gain_to_split=0.25; max_depth=7 : y = 0.93 : 234.5 secs : infill_ei
#
# Mon Nov 03 03:39:28 PM 2025 AUC 0.931042311138663
#
# [mbo] 29: learning_rate=0.0123; num_leaves=84; feature_fraction=0.503; bagging_fraction=0.964; min_data_in_leaf=114; lambda_l1=3.91; lambda_l2=2.96; min_gain_to_split=0.322; max_depth=7 : y = 0.931 : 254.9 secs : infill_ei
#
# Saved the current state after iteration 30 in the file bayesiana.RDATA.
#
# Mon Nov 03 03:43:51 PM 2025 AUC 0.930692075836553
#
# [mbo] 30: learning_rate=0.0176; num_leaves=87; feature_fraction=0.501; bagging_fraction=0.962; min_data_in_leaf=189; lambda_l1=1.88; lambda_l2=4.53; min_gain_to_split=0.149; max_depth=7 : y = 0.931 : 261.8 secs : infill_ei
#
# Mon Nov 03 03:47:46 PM 2025 AUC 0.930575314483133
#
# [mbo] 31: learning_rate=0.0452; num_leaves=36; feature_fraction=0.505; bagging_fraction=0.922; min_data_in_leaf=28; lambda_l1=1.71; lambda_l2=4.07; min_gain_to_split=0.107; max_depth=5 : y = 0.931 : 234.1 secs : infill_ei
#
# Mon Nov 03 03:49:59 PM 2025 AUC 0.930041747068781
#
# [mbo] 32: learning_rate=0.0312; num_leaves=33; feature_fraction=0.878; bagging_fraction=0.901; min_data_in_leaf=20; lambda_l1=1.73; lambda_l2=4.17; min_gain_to_split=0.0172; max_depth=5 : y = 0.93 : 132.4 secs : infill_ei
#
# Saved the current state after iteration 33 in the file bayesiana.RDATA.
#
# Mon Nov 03 03:52:22 PM 2025 AUC 0.929888767578704
#
# [mbo] 33: learning_rate=0.0416; num_leaves=39; feature_fraction=0.602; bagging_fraction=0.701; min_data_in_leaf=68; lambda_l1=1.04; lambda_l2=7.59; min_gain_to_split=0.455; max_depth=5 : y = 0.93 : 141.8 secs : infill_ei
#
# Mon Nov 03 03:56:38 PM 2025 AUC 0.92993295948999
#
# [mbo] 34: learning_rate=0.0106; num_leaves=65; feature_fraction=0.531; bagging_fraction=0.933; min_data_in_leaf=195; lambda_l1=4.83; lambda_l2=2.61; min_gain_to_split=0.334; max_depth=10 : y = 0.93 : 254.9 secs : infill_ei
#
# Mon Nov 03 04:01:01 PM 2025 AUC 0.930848569741521
#
# [mbo] 35: learning_rate=0.0159; num_leaves=79; feature_fraction=0.501; bagging_fraction=0.999; min_data_in_leaf=123; lambda_l1=0.585; lambda_l2=1.46; min_gain_to_split=0.13; max_depth=7 : y = 0.931 : 262.3 secs : infill_ei
#
# Saved the final state in the file bayesiana.RDATA
#
# Saved the final state in the file bayesiana.RDATA

# %%
tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)
colnames( tb_bayesiana)
# Out:
#  [1] "learning_rate"     "num_leaves"        "feature_fraction"
#  [4] "bagging_fraction"  "min_data_in_leaf"  "lambda_l1"
#  [7] "lambda_l2"         "min_gain_to_split" "max_depth"
# [10] "y"                 "dob"               "eol"
# [13] "error.message"     "exec.time"         "ei"
# [16] "error.model"       "train.time"        "prop.type"
# [19] "propose.time"      "se"                "mean"

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

tb_bayesiana[, iter := .I]

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file= "BO_log.txt",
  sep= "\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]


PARAM$out$lgbm$y <- tb_bayesiana[1, y]

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
print(PARAM$out$lgbm$mejores_hiperparametros)
print(PARAM$out$lgbm$y)
# Out:
#    learning_rate num_leaves feature_fraction bagging_fraction min_data_in_leaf
#            <num>      <int>            <num>            <num>            <int>
# 1:    0.01610076         43        0.5244073        0.9891286               80
#    lambda_l1 lambda_l2 min_gain_to_split max_depth
#        <num>     <num>             <num>     <int>
# 1:  1.511068  2.120467         0.2562214         7
# [1] 0.9310652

# %% [markdown]
# # Segunda Corrida
#
#
# PARAM$hypeparametertuning$hs <- makeParamSet(
#   makeNumericParam("learning_rate", lower = 0.01, upper = 0.05),
#   makeIntegerParam("num_leaves", lower = 16L, upper = 128L),
#   makeNumericParam("feature_fraction", lower = 0.5, upper = 0.9),
#   makeNumericParam("bagging_fraction", lower = 0.7, upper = 1.0),
#   makeIntegerParam("min_data_in_leaf", lower = 20L, upper = 200L),
#   makeNumericParam("lambda_l1", lower = 0, upper = 10),
#   makeNumericParam("lambda_l2", lower = 0, upper = 10),
#   makeNumericParam("min_gain_to_split", lower = 0, upper = 0.5),
#   makeIntegerParam("max_depth", lower = -1L, upper = 10L)
# )
#
# Resultados
#
#
#     boosting: 'gbdt'
#     objective: 'binary'
#     metric: 'auc'
#     first_metric_only: FALSE
#     boost_from_average: TRUE
#     feature_pre_filter: FALSE
#     force_row_wise: TRUE
#     verbosity: -100
#     seed: 100007
#     max_depth: 7
#     min_gain_to_split: 0.2562214
#     min_sum_hessian_in_leaf: 0.001
#     lambda_l1: 1.511068
#     lambda_l2: 2.120467
#     max_bin: 31
#     bagging_fraction: 0.9891286
#     pos_bagging_fraction: 1
#     neg_bagging_fraction: 1
#     is_unbalance: FALSE
#     scale_pos_weight: 1
#     drop_rate: 0.1
#     max_drop: 50
#     skip_drop: 0.5
#     extra_trees: FALSE
#     num_iterations: 1200
#     learning_rate: 0.01610076
#     feature_fraction: 0.5244073
#     num_leaves: 43
#     min_data_in_leaf: 80
#
#
#
#     Kaggle: 57.927

# %% [markdown]
# ## 2.3  Produccion

# %% [markdown]
# ### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %%
setwd("/content/buckets/b1/exp")
experimento <- paste0("exp", PARAM$experimento)
dir.create(experimento, showWarnings= FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento ))

# %% [markdown]
# #### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
# clase01
dataset[, clase01 := ifelse(clase_ternaria %in% c("BAJA+1", "BAJA+2"), 1L, 0L)]

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[, campos_buenos, with= FALSE]),
  label= dataset_train[, clase01]
)

# %% [markdown]
# #### Final Training Hyperparameters

# %%
param_final <- modifyList(PARAM$lgbm$param_fijos,
  PARAM$out$lgbm$mejores_hiperparametros)

param_final
# Out:
# $boosting
# [1] "gbdt"
#
# $objective
# [1] "binary"
#
# $metric
# [1] "auc"
#
# $first_metric_only
# [1] FALSE
#
# $boost_from_average
# [1] TRUE
#
# $feature_pre_filter
# [1] FALSE
#
# $force_row_wise
# [1] TRUE
#
# $verbosity
# [1] -100
#
# $seed
# [1] 100007
#
# $max_depth
# [1] 7
#
# $min_gain_to_split
# [1] 0.2562214
#
# $min_sum_hessian_in_leaf
# [1] 0.001
#
# $lambda_l1
# [1] 1.511068
#
# $lambda_l2
# [1] 2.120467
#
# $max_bin
# [1] 31
#
# $bagging_fraction
# [1] 0.9891286
#
# $pos_bagging_fraction
# [1] 1
#
# $neg_bagging_fraction
# [1] 1
#
# $is_unbalance
# [1] FALSE
#
# $scale_pos_weight
# [1] 1
#
# $drop_rate
# [1] 0.1
#
# $max_drop
# [1] 50
#
# $skip_drop
# [1] 0.5
#
# $extra_trees
# [1] FALSE
#
# $num_iterations
# [1] 1200
#
# $learning_rate
# [1] 0.01610076
#
# $feature_fraction
# [1] 0.5244073
#
# $num_leaves
# [1] 43
#
# $min_data_in_leaf
# [1] 80

# %% [markdown]
# #### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
# este punto es muy SUTIL  y será revisado en la Clase 05

param_normalizado <- copy(param_final)
param_normalizado$min_data_in_leaf <-  round(param_final$min_data_in_leaf / PARAM$trainingstrategy$undersampling)

# %%
  # entreno LightGBM

  modelo_final <- lgb.train(
    data= dtrain,
    param= param_normalizado
  )

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(modelo_final))
archivo_importancia <- "impo.txt"

fwrite(tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(modelo_final, "modelo.txt" )

# %% [markdown]
# ### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
# aplico el modelo a los datos sin clase
dfuture <- dataset[foto_mes == 202109]

# aplico el modelo a los datos nuevos
prediccion <- predict(
  modelo_final,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# #### Tabla Prediccion

# %%
# tabla de prediccion

tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion ]

# grabo las probabilidad del modelo
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# Kaggle Competition Submit

# %%
# genero archivos con los  "envios" mejores
# suba TODOS los archivos a Kaggle

# ordeno por probabilidad descendente
setorder(tb_prediccion, -prob)

dir.create("kaggle")

for (envios in PARAM$kaggle$cortes) {

  tb_prediccion[, Predicted := 0L] # seteo inicial a 0
  tb_prediccion[1:envios, Predicted := 1L] # marclo los primeros

  archivo_kaggle <- paste0("./kaggle/KA", PARAM$experimento, "_", envios, ".csv")

  # grabo el archivo
  fwrite(tb_prediccion[, list(numero_de_cliente, Predicted)],
    file= archivo_kaggle,
    sep= ","
  )

  # subida a Kaggle, armo la linea de comando
  comando <- "kaggle competitions submit"
  competencia <- paste("-c", PARAM$kaggle$competencia)
  arch <- paste( "-f", archivo_kaggle)

  mensaje <- paste0("-m 'envios=", envios,
  "  semilla=", PARAM$semilla_primigenia,
    "'" )

  linea <- paste( comando, competencia, arch, mensaje)

  salida <- system(linea, intern=TRUE) # el submit a Kaggle
  cat(salida, "\n")
  Sys.sleep(45)
}
# Out:
# Successfully submitted to LaboI 2025 virtual analista sr
# Successfully submitted to LaboI 2025 virtual analista sr
# Successfully submitted to LaboI 2025 virtual analista sr
# Successfully submitted to LaboI 2025 virtual analista sr
# Successfully submitted to LaboI 2025 virtual analista sr

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Mon Nov 03 04:07:39 PM 2025"

# %% [markdown]
# Finalmente usted deberá cargar el resultado de su corrida en la Google Sheet Colaborativa,  hoja **TareaHogar-05**
# <br> Siéntase libre de agregar las columnas que hagan falta a la planilla

# %% [markdown]
# Seguramente usted realice varias corridas de este script con distintos conjuntos de hiperparámetros, siempre cambiandole el nombre al script  y también cambiando el nombre del experimento,  deberá TODAS esas corridas en distintas lineas de la  Google Sheet Colaborativa, hoja **TareaHogar-05**

# %% [markdown]
# Siéntase libre de agregar columnas a la hoja **TareaHogar-05**  en caso de ser necesario.
